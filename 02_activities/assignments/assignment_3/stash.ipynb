# %%
# Plot the data with seaborn barplot

#plt.figure(figsize=(10, 6))
fig, ax = plt.subplots(figsize=(10, 6))

ax = sns.barplot(
    data=agg_data,
    x='YEAR',
    y='COUNT',
    hue='POLL_RESULT',
    palette={                       # colour-blind friendly palette
        'In Favour': '#009E73',
        'Opposed': '#D55E00',
        'Response Rate Not Met': "#999999"
    }
)

# Add bar labels
for c in ax.containers:
    ax.bar_label(
        c,
        fmt='%d',
        label_type='edge',
        padding=2,
        fontsize=8,
        fontweight='bold',
        color='black'
    )

plt.title(f'Polls Results by Year - {application_type.upper()}', fontsize=14, fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Number of Polls / Applications')
plt.legend(title='Poll Result', bbox_to_anchor=(1.3, 1))

# Save the above visualization on disk
fig.savefig('./using_python_poll_results_by_year.png', dpi=300, bbox_inches='tight')

plt.show()
